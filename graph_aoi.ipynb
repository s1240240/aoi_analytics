# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
origin_data = pd.read_csv("2017_katudon.csv")
origin_data.head()
# Out:
#              date youbi month   SKUcode              item  urisuu  urikin  \
# 0  2017年01月01日(日)     日    1月  92851023  三元豚手作りロースのソースかつ重       4    1792
# 1  2017年01月02日(月)     月    1月  92851023  三元豚手作りロースのソースかつ重      12    3532
# 2  2017年01月03日(火)     火    1月  92851023  三元豚手作りロースのソースかつ重      12    4380
# 3  2017年01月04日(水)     水    1月  92851023  三元豚手作りロースのソースかつ重      12    3983
# 4  2017年01月05日(木)     木    1月  92851023  三元豚手作りロースのソースかつ重       4    1942
#
#    nesage  nine_urisuu  nine_urikin        ...         eight_nesage  \
# 0       1          NaN          NaN        ...                  NaN
# 1      11          NaN          NaN        ...                  NaN
# 2      10          NaN          NaN        ...                  NaN
# 3       9          NaN          NaN        ...                  NaN
# 4       1          NaN          NaN        ...                  NaN
#
#    pm_nine_urisuu  pm_nine_urikin  pm_nine_nesage  pm_ten_urisuu  \
# ...

# %%
#sns.pairplot(data=origin_data,hue="youbi",palette="gray")

# %%
jan=origin_data.iloc[0:1]
jan2=jan[
        ['date','youbi','urisuu','urikin','nine_urisuu','ten_urisuu','eleven_urisuu','noon_urisuu','one_urisuu',\
              'two_urisuu','three_urisuu','four_urisuu','five_urisuu','six_urisuu','seven_urisuu',\
              'eight_urisuu','pm_nine_urisuu','pm_ten_urisuu','pm_eleve_urisuu','six_nesage','seven_nesage','eight_nesage','pm_nine_nesage','pm_ten_nesage','pm_eleven_nesage']
        ]
#sns.pairplot(data=origin_data,hue="youbi",palette="gray")
#jan3.head()
#jan2.plot.bar()
#print(jan2)

# %%
jan=origin_data.iloc[0:1]
jan2=jan[
        ['youbi','urisuu','urikin','nine_urisuu','ten_urisuu','eleven_urisuu','noon_urisuu','one_urisuu',\
              'two_urisuu','three_urisuu','four_urisuu','five_urisuu','six_urisuu','seven_urisuu',\
              'eight_urisuu','pm_nine_urisuu','pm_ten_urisuu','pm_eleve_urisuu','six_nesage','seven_nesage','eight_nesage','pm_nine_nesage','pm_ten_nesage','pm_eleven_nesage']
        ]

# %%
jan2.head()
# Out:
#   youbi  urisuu  urikin  nine_urisuu  ten_urisuu  eleven_urisuu  noon_urisuu  \
# 0     日       4    1792          NaN         3.0            NaN          NaN
#
#    one_urisuu  two_urisuu  three_urisuu        ...         eight_urisuu  \
# 0         NaN         NaN           NaN        ...                  NaN
#
#    pm_nine_urisuu  pm_ten_urisuu  pm_eleve_urisuu  six_nesage  seven_nesage  \
# 0             NaN            NaN              NaN         NaN           1.0
#
#    eight_nesage  pm_nine_nesage  pm_ten_nesage  pm_eleven_nesage
# 0           NaN             NaN            NaN               NaN
#
# [1 rows x 24 columns]

# %%
for i in range(100):
    jan=origin_data.iloc[i:i+1]
    jan3=jan[
            ['date','youbi','nine_urisuu','ten_urisuu','eleven_urisuu','noon_urisuu','one_urisuu',\
                  'two_urisuu','three_urisuu','four_urisuu','five_urisuu','six_urisuu','seven_urisuu',\
                  'eight_urisuu','pm_nine_urisuu','pm_ten_urisuu','pm_eleve_urisuu']
            ]
    jan3=jan3.set_index('date')
    #print(jan3)
    #jan3.head()
    #jan2.head()
    jan3.plot.bar()
    #jan3.plot(kind='bar');
# Out:
# /anaconda3/lib/python3.6/site-packages/matplotlib/pyplot.py:528: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)

# %%
#print(jan3)
jan3=origin_data[
            ['eleven_urisuu','noon_urisuu','one_urisuu',\
                  'two_urisuu','three_urisuu','four_urisuu','five_urisuu','six_urisuu','seven_urisuu',\
                  'eight_urisuu','pm_nine_urisuu']
            ]
jan3=jan3.fillna(0)
fig=plt.figure()
jan3.plot(subplots=True,figsize=(20,20),sharex=True,sharey=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x1a24a35a58>,
# ...
#       dtype=object)

# %%
for i in range(10):
    print(jan4.iloc[:360,i+1])

# %%
jan3=jan.set_index('date')
jan2=jan2.fillna(0)

# %%
jan3.head()
#sns.pairplot(data=origin_data,palette="gray")

# %%
#sns.pairplot(data=jan2,hue="youbi")

# %%
#print(jan2.groupby("youbi").mean())

# %%
#import os
#os.chdir('/Users/watanabeyui/')
#os.getcwd()
#os.chdir('/Users/watanabeyui/Downloads/Past_weather_data')
#os.getcwd()
#weather=pd.read_csv("weather2.csv")
#jan2=pd.merge(jan2,weather,left_index=True,right_index=True)
#jan2=jan2.rename(columns={'気温(℃)平均': 'avg_temp'})
#jan2=jan2.rename(columns={'降水量(mm)合計': 'weather'})

# %%
#print(jan2.groupby("weather").mean())
